# %% [markdown]
# <div style="background-color:#ecf0f1; border-left:6px solid #e74c3c; padding:20px 30px; border-radius:6px;">
#   <h1 style="color:#2c3e50; margin:0;">Séance 7 — Les Fonctions en Python</h1>
#   <p style="color:#7f8c8d; margin:8px 0 0 0;">
#     <em>"Un programme informatique fait ce que vous lui dites de faire,
#     pas ce que vous voudriez qu'il fasse."</em><br>
#     <span style="color:#1a1a2e;">— Troisième loi de Greer, dérivée de la loi de Murphy</span>
#   </p>
# </div>
#
# ## Objectifs de cette séquence
#
# À la fin de cette séquence, vous serez capable de :
#
# - Expliquer ce qu'est une fonction et pourquoi on l'utilise
# - Définir vos propres fonctions avec ou sans paramètres
# - Distinguer une fonction qui retourne une valeur d'une qui n'en retourne pas
# - Comprendre la portée locale et globale des variables
# - Résoudre des exercices pratiques en utilisant des fonctions

# %% [markdown]
# <div style="background-color:#2c3e50; padding:16px 24px; border-radius:8px; margin:30px 0;">
#   <h2 style="color:#ecf0f1; margin:0; font-family:monospace;">Séance 1 — Découverte des fonctions</h2>
# </div>

# %% [markdown]
# <div style="background-color:#eaf4ea; border-left:5px solid #27ae60; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Avant la théorie — Observez et exécutez</b><br>
# Exécutez le code ci-dessous. Que remarquez-vous ?<br>
# Que faudrait-il changer si le message changeait pour 30 élèves ?
# </div>

# %%
# Executez ce code et observez ce qui se passe
print("Bonjour Alice !")
print("Bienvenue dans le cours.")
print("---")

print("Bonjour Bob !")
print("Bienvenue dans le cours.")
print("---")

print("Bonjour Charlie !")
print("Bienvenue dans le cours.")
print("---")

# Question : si on voulait accueillir 20 eleves,
# combien de lignes faudrait-il ecrire ?
# Que se passe-t-il si on veut changer "Bienvenue" en "Bonne journee" ?
# Out:
# Bonjour Alice !
# Bienvenue dans le cours.
# ---
# Bonjour Bob !
# Bienvenue dans le cours.
# ---
# Bonjour Charlie !
# Bienvenue dans le cours.
# ---

# %% [markdown]
# ---
# ## 1. Pourquoi utiliser des fonctions ?
#
# Une **fonction** est un ensemble d'**instructions**, dépendant généralement d'un ou de
# plusieurs **paramètres**, qui effectue une **action**. Une fois définie,
# elle peut être appelée depuis n'importe où dans le programme.
#
# Utiliser des fonctions permet de :
#
# - **Éviter les répétitions** de code (principe DRY : *Don't Repeat Yourself*)
# - **Décomposer** un programme complexe en sous-programmes simples
# - Mieux **structurer** et rendre le code plus lisible
# - **Réutiliser** la même fonction dans différents programmes

# %% [markdown]
# ## Une fonction, c'est quoi ?
# <div style="background-color:#eaf4ea; border-left:5px solid #27ae60; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Imagine : une boîte noire  </b><br>
#
# - Tu lui donnes des **entrées** (les paramètres)
# - Elle fait quelque chose à l'intérieur (les instructions)
# - Elle te rend un **résultat** (la valeur retournée)
# ```
# [entrée] --> [ boîte noire ] --> [sortie]
# ```
#
# Exemple du quotidien : **une calculatrice**.
# Tu entres les nombres `3` et `5`, tu appuies sur `+`,  elle te rend la valeur`8`.
# Peu importe comment elle calcule à l'intérieur — tu n'as pas besoin de le savoir.
#
# C'est exactement ce que fait une fonction en Python.
#
# </div>

# %% [markdown]
# ### Exemple : sans vs avec fonction
# #### Retour au premier exemple : accueil

# %%
# --- SANS fonction : le message de bienvenue est répété 3 fois ---
print("Bonjour Alice !")
print("Bienvenue dans le cours.")
print("---")

print("Bonjour Bob !")
print("Bienvenue dans le cours.")
print("---")

print("Bonjour Charlie !")
print("Bienvenue dans le cours.")
print("---")
# Out:
# Bonjour Alice !
# Bienvenue dans le cours.
# ---
# Bonjour Bob !
# Bienvenue dans le cours.
# ---
# Bonjour Charlie !
# Bienvenue dans le cours.
# ---

# %%
# --- AVEC fonction : le code est écrit une seule fois, appelé 3 fois ---
def accueil(prenom):
    # Affiche un message de bienvenue personnalisé
    print("Bonjour", prenom)
    print("Bienvenue dans le cours.")
    print("---")

accueil("Alice")
accueil("Bob")
accueil("Charlie")
# Out:
# Bonjour Alice
# Bienvenue dans le cours.
# ---
# Bonjour Bob
# Bienvenue dans le cours.
# ---
# Bonjour Charlie
# Bienvenue dans le cours.
# ---

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice d'application - A</b> — Modifier la fonction <code>accueil</code> pour qu'elle affiche aussi
# "Bonne chance !" après le message. Appeler la fonction avec trois prénoms de votre choix.
# </div>

# %%
# Mini-exercice A — Complétez ici
def accueil(prenom):
    # À compléter
    pass

accueil("Alice")
accueil("Bob")
accueil("Mia")

# %% [markdown]
# ---
# ## 2. Fonctions déjà utilisées
#
# Vous avez déjà utilisé des fonctions Python sans le savoir !
#
# | Fonction | Retourne quelque chose ? | Exemple |
# |----------|--------------------------|--------|
# | `print()` | Non | `print("Bonjour")` |
# | `input()` | Oui (une chaîne) | `nom = input("Votre nom ?")` |
# | `int()` | Oui (un entier) | `x = int("35")` |
# | `len()` | Oui (un entier) | `n = len("bonjour")` |
# | `randint()` | Oui (un entier) | `n = randint(1, 10)` |
#
# La syntaxe générale d'un appel de fonction est :
#
# ```python
# nom_fonction(param1, param2, ..., paramN)
# ```

# %%
from random import randint

x = int("35")            # convertit la chaîne "35" en entier
n = len("informatique")  # retourne le nombre de caractères
nb = randint(1, 10)      # retourne un entier aléatoire entre 1 et 10

print("x =", x)
print("longueur =", n)
print("aléatoire =", nb)
# Out:
# x = 35
# longueur = 12
# aléatoire = 7

# %% [markdown]
# ---
# ## 3. Définir ses propres fonctions
#
# ### Syntaxe générale

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/d%C3%A9finir_ses_propres_fonctions.PNG" width="600">
# </div>

# %% [markdown]
# Points importants :
#
# - Le mot-clé `def` annonce la définition
# - Le nom suit les mêmes règles que les variables (minuscules, pas d'espaces)
# - Les `:` sont obligatoires après la parenthèse fermante
# - Le corps est **indenté** (4 espaces ou touche Tab)
# - `return` est **optionnel** — une fonction sans `return` ne renvoie rien
#
# ### Différence : définition vs appel

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/definition_et_appel.PNG" width="600">
# </div>

# %% [markdown]
# <div style="background-color:#d1ecf1; border-left:5px solid #17a2b8; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>À retenir :</b> La définition d'une fonction <strong>ne fait rien toute seule</strong>. Il faut <strong>appeler</strong> la fonction pour que le code s'exécute.
# </div>

# %% [markdown]
# ---
# ## 4. Les quatre types de fonctions
#
# On distingue les fonctions selon deux critères : ont-elles des **paramètres** ? Renvoient-elles une **valeur** ?

# %% [markdown]
# <div style="background-color:#fdfaf3; border-left:5px solid #f39c12; padding:16px 20px; border-radius:4px; margin:14px 0;">
# <b>Comment choisir le bon type de fonction ?</b><br><br>
# Avant d'écrire une fonction, pose-toi deux questions dans l'ordre :
# <ol>
#   <li><b>Ma fonction a-t-elle besoin d'information pour travailler ?</b><br>
#   Si oui &rarr; elle a des <b>paramètres</b>.<br>
#   Si non &rarr; elle n'en a pas.<br><br>
#   <i>Exemple : calculer le cube d'un nombre nécessite de connaître ce nombre &rarr; paramètre obligatoire.<br>
#   Afficher la date du jour ne dépend d'aucune donnée extérieure &rarr; pas de paramètre.</i>
#   </li>
#   <br>
#   <li><b>La fonction doit-elle fournir un résultat utilisable ailleurs dans le code ?</b><br>
#   Si oui &rarr; elle doit avoir un <code>return</code>.<br>
#   Si non (elle affiche, elle modifie, elle fait une action) &rarr; pas de <code>return</code>.<br><br>
#   <i>Exemple : si tu veux stocker le résultat dans une variable ou l'utiliser dans un calcul &rarr; <code>return</code> indispensable.<br>
#   Si la fonction se contente d'afficher un message &rarr; pas besoin de <code>return</code>.</i>
#   </li>
# </ol>
# </div>

# %% [markdown]
# ### Tableau de décision
#
# <table style="width:100%; border-collapse:collapse; font-size:0.95em; margin:14px 0;">
#   <thead>
#     <tr style="background-color:#2c3e50; color:white;">
#       <th style="padding:12px 16px; text-align:left; width:18%;"></th>
#       <th style="padding:12px 16px; text-align:left; width:41%;">Sans <code>return</code></th>
#       <th style="padding:12px 16px; text-align:left; width:41%;">Avec <code>return</code></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background-color:#f4f6f7;">
#       <td style="padding:12px 16px; font-weight:bold; border-right:2px solid #ddd;">Sans paramètre</td>
#       <td style="padding:12px 16px; border-right:1px solid #ddd;">
#         <code>def compteur3():</code><br>
#         <span style="color:#555;">affiche 0, 1, 2 — ne renvoie rien</span>
#       </td>
#       <td style="padding:12px 16px;">
#         <code>def trois_au_cube():</code><br>
#         <span style="color:#555;">renvoie 27</span>
#       </td>
#     </tr>
#     <tr style="background-color:#ffffff;">
#       <td style="padding:12px 16px; font-weight:bold; border-right:2px solid #ddd;">Avec paramètre(s)</td>
#       <td style="padding:12px 16px; border-right:1px solid #ddd;">
#         <code>def accueil(prenom):</code><br>
#         <span style="color:#555;">affiche un message — ne renvoie rien</span>
#       </td>
#       <td style="padding:12px 16px;">
#         <code>def cube(nombre):</code><br>
#         <span style="color:#555;">renvoie <code>nombre ** 3</code></span>
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="background-color:#d1ecf1; border-left:5px solid #17a2b8; padding:10px 14px; border-radius:4px; margin:10px 0;">
# <b>Règle pratique :</b> <br>
# - Si tu écris <code>resultat = ma_fonction(...)</code> ou si tu utilises
# la fonction dans une expression, elle <strong>doit</strong> avoir un <code>return</code>. <br>
# - Si tu appelles juste <code>ma_fonction(...)</code> sans récupérer quoi que ce soit, un <code>return</code> n'est pas nécessaire.
# </div>

# %% [markdown]
# ### 4.1 Sans paramètre, sans renvoi (pas de `return`)

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/fonction_sans_paramètre_sans_renvoi.png" width="600">
# </div>

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exemple d'application - A</b>
# </div>

# %%
# Fonction sans paramètre, sans return
def compteur3():
    i = 0
    while i < 3:
        print(i)
        i = i + 1

compteur3()  # Appel — les parenthèses sont obligatoires !
# Out:
# 0
# 1
# 2

# %% [markdown]
# ### 4.2 Sans paramètre, avec renvoi (`return`)

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/fonction_sans_parametre_avec_renvoi.png" width="600">
# </div>

# %%
# Fonction sans paramètre, avec return
def trois_au_cube():
    return 3 ** 3

resultat = trois_au_cube()
print(resultat)  # affiche : 27
# Out:
# 27

# %% [markdown]
# ### 4.3 Avec paramètre, avec renvoi

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/fonction_avec_parametre_avec_renvoi.png" width="600">
# </div>

# %%
# Fonction avec un paramètre, avec return
def cube(nombre):
    return nombre ** 3

a = cube(2)   # a vaut 8
b = cube(5)   # b vaut 125
print(a + b)  # affiche : 133

# %% [markdown]
# La valeur renvoyée par la fonction **peut être mémorisée** : `a = cube(2)`.
# La même fonction peut être **appelée plusieurs fois** avec des arguments différents.

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice d'application B</b> — Écrire une fonction <code>aire_rectangle(longueur, largeur)</code> qui retourne l'aire.
# Tester avec au moins deux rectangles.
# </div>

# %%
# Exercice d'application B — Complétez ici
def aire_rectangle(longueur, largeur):
    # Retourne l'aire du rectangle
    pass

print(aire_rectangle(5, 3))   # attendu : 15
print(aire_rectangle(10, 4))  # attendu : 40

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 1a : lecture de code </b><br>
# <b>- Lisez le programme suivant et
# prédisez ce qu'il affiche avant de l'exécuter.</b>
# </div>

# %%
# Exercice 1a — Que fait mystere ? Qu'affiche-t-il ?
def mystere(n):
    if n % 2 == 0:
        return True
    else:
        return False

a = mystere(150)
b = mystere(116)
print(a, b)

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 1b : lecture de code </b><br>
# <b>- Lisez le programme suivant et
# prédisez ce qu'il affiche avant de l'exécuter.</b>
# </div>

# %%
# Exercice 1b — Que fait cette fonction ?
def age(date):
    return 2023 - date

d = int(input("En quelle année êtes-vous né·e ? "))
a = age(d)
if a > 18:
    print("vous pouvez entrer")
else:
    print("vous devez être accompagné·e")

# %% [markdown]
# ### 4.4 Avec plusieurs paramètres et renvoi

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/fonction_avec_plusieurs_parametres_et_renvoi.png" width="600">
# </div>

# %%
# Fonction avec deux paramètres, avec return
def puissance(nombre, exposant):
    return nombre ** exposant

print(puissance(2, 3))   # affiche : 8
print(puissance(10, 4))  # affiche : 10000

# %% [markdown]
# <div style="background-color:#f0eafa; border-left:5px solid #8e44ad; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Application — Exemple complet à imiter</b><br>
# Lisez et exécutez cet exemple. Repérez : le nom de la fonction, ses parametres, le <code>return</code>, et l'appel.
# </div>

# %%
# Exemple complet : somme de 2 nombres
def somme_2nb(a, b):       # deux parametres
    total = a + b          # calcul intermediaire
    return total           # renvoi du resultat

# Appel et recuperation du resultat dans une variable
resultat = somme_2nb(3, 7)
print("3 + 7 =", resultat)             # affiche : 3 + 7 = 10

# On peut aussi appeler directement dans print()
print("10 + 25 =", somme_2nb(10, 25))  # affiche : 10 + 25 = 35

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 1c : lecture de code </b><br>
# <b>- Lisez le programme suivant et
# prédisez ce qu'il affiche avant de l'exécuter.</b> : Que retourne <code>listepropre</code>
# </div>

# %%
# Exercice 1c — Prédisez, puis exécutez
def listepropre(liste):
    lp = []
    for e in liste:
        if e != 0:
            lp.append(e)
    return lp

liste = [1, 0, 2, 4, 5, 0, 0, 4]
lp = listepropre(liste)
print(lp)

liste2 = [0, 0, 0, 0]
lp2 = listepropre(liste2)
print(lp2)

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 1d : lecture de code </b><br>
# <b>- Lisez le programme suivant et
# prédisez ce qu'il affiche avant de l'exécuter.</b>>
# </div>

# %%
# Exercice 1d — Que vaut resultat ? Pourquoi ?
def toto():
    print("toto")

resultat = toto()
print(resultat)

# %% [markdown]
# <div style="background-color:#d1ecf1; border-left:5px solid #17a2b8; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>À retenir :</b> Une fonction sans <code>return</code> renvoie automatiquement <code>None</code>. C'est pourquoi <code>print(resultat)</code> affiche <code>None</code>.
# </div>

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 2:  Somme de trois nombres</b><br>
# <b>Écrire une fonction qui prend 3 nombres en paramètre et retourne leur somme.</b>
# </div>

# %%
# Exercice 2 — Complétez ici
def somme_3nb(a, b, c):
    # Retourne la somme de a, b et c
    pass

print(somme_3nb(1, 2, 3))     # attendu : 6
print(somme_3nb(10, -5, 3))   # attendu : 8

# %% [markdown]
# <div style="background-color:#f0eafa; border-left:5px solid #8e44ad; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Application — Exemple complet à imiter — Accumulateur dans une liste</b><br>
# Cette fonction calcule la <b>somme</b> des elements d'une liste.<br>
# Observez comment on initialise un accumulateur <b>avant</b> la boucle.
# </div>

# %%
# Exemple complet : somme des elements d'une liste
def somme_liste(liste):
    total = 0               # accumulateur initialise a 0 (element neutre)
    for nombre in liste:    # on parcourt chaque element
        total = total + nombre   # on accumule
    return total            # on renvoie le resultat final

print(somme_liste([1, 2, 3, 4]))  # affiche : 10
print(somme_liste([10, -5, 3]))   # affiche : 8
print(somme_liste([]))            # affiche : 0 — coherent ?

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 3 — Produit d'une liste</b>
# </div>

# %% [markdown]
# Écrire une fonction qui prend en paramètre une **liste de nombres** et retourne leur **produit**.
# Par exemple : `produit([3, 2, -1, 5])` retourne `-30`.
# Tester avec au moins deux listes. Que fait votre fonction si une liste **vide** lui est passée ? Est-ce cohérent ?

# %%
# Exercice 3 — Complétez ici
def produit(liste):
    # Indice : initialiser le résultat à 1 (élément neutre de la multiplication)
    pass

print(produit([3, 2, -1, 5]))  # attendu : -30
print(produit([1, 2, 3, 4]))   # attendu : 24
print(produit([]))             # que retourne votre fonction ? Est-ce cohérent ?

# %% [markdown]
# <div style="background-color:#27ae60; padding:12px 20px; border-radius:6px; margin:20px 0; text-align:center;">
#   <b style="color:white; font-size:1.1em;">Fin de la séance 1</b>
# </div>

# %% [markdown]
# <div style="background-color:#2c3e50; padding:16px 24px; border-radius:8px; margin:30px 0;">
#   <h2 style="color:#ecf0f1; margin:0; font-family:monospace;">Séance 2 — Chaînes, portée des variables et exercices avancés</h2>
# </div>

# %% [markdown]
# <div style="background-color:#eaf4ea; border-left:5px solid #27ae60; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Avant la théorie — Observez et exécutez</b><br>
# Exécutez les deux codes ci-dessous et comparez les résultats.<br>
# Quelle est la différence entre utiliser <code>print</code> et utiliser <code>return</code> dans une fonction ?
# </div>

# %%
# Version A : la fonction affiche directement (print)
def saluer_a(prenom):
    print("Bonjour", prenom)

resultat_a = saluer_a("Alice")
print("resultat_a vaut :", resultat_a)   # que vaut resultat_a ?

print("---")

# Version B : la fonction renvoie une valeur (return)
def saluer_b(prenom):
    return "Bonjour " + prenom

resultat_b = saluer_b("Alice")
print("resultat_b vaut :", resultat_b)   # que vaut resultat_b ?

# %% [markdown]
# ### 4.5 Le `return` interrompt la fonction
#
# Dès qu'un `return` est atteint, la fonction s'arrête **immédiatement**.
# Il peut y avoir plusieurs `return`, mais un seul sera exécuté.

# %%
# Plusieurs return possibles — le premier atteint interrompt la fonction
def est_premier(nb):
    for d in range(2, nb):
        if nb % d == 0:
            return False   # divisible => pas premier, on sort immédiatement
    return True            # aucun diviseur trouvé => premier

print(est_premier(7))    # True
print(est_premier(4))    # False
print(est_premier(13))   # True

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice d'application C</b><br>
# <b>Écrire une fonction <code>est_pair(n)</code> qui retourne <code>True</code> si n est pair,
# <code>False</code> sinon. Utiliser l'opérateur modulo <code>%</code>.
# Tester avec 4, 7 et 100.
# </div>

# %%
# Exercice d'application C — Complétez ici
def est_pair(n):
    # Utilisez l'opérateur modulo %
    pass

print(est_pair(4))    # True
print(est_pair(7))    # False
print(est_pair(100))  # True

# %% [markdown]
# ---
# ## 5. Portée des variables : locale vs globale
#
# Une variable définie **dans** une fonction est **locale** : elle n'existe que pendant
# l'exécution de cette fonction.
# Une variable définie **hors** d'une fonction est **globale** : visible à l'intérieur,
# mais la fonction **ne peut pas la modifier**.

# %% [markdown]
# <div style="text-align:left;">
#   <img src="https://raw.githubusercontent.com/HjrManel/Cours_python/main/espace_et_portee_des_variables.png" width="600">
# </div>

# %%
def test():
    b = 5          # variable locale à la fonction
    print(a, b)    # voit la variable globale a

a = 2  # variable globale
b = 7  # variable globale (distincte du b local dans test)

test()         # affiche : 2 5
print(a, b)    # affiche : 2 7  — le b global n'a pas changé

# %% [markdown]
# <div style="background-color:#f8d7da; border-left:5px solid #dc3545; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Attention :</b> Le <code>b</code> dans la fonction est une copie <strong>locale</strong>. Modifier <code>b</code> à l'intérieur de <code>test()</code> ne change pas le <code>b</code> global !
# </div>

# %%
# Vérification : la variable locale disparaît après la fonction
def ma_fonction():
    x_local = 99
    print("Dans la fonction, x_local =", x_local)

ma_fonction()

# Décommenter la ligne suivante pour voir l'erreur :
# print(x_local)  # NameError : x_local n'existe pas ici

# %% [markdown]
# ---
# ## 6. Manipulation de chaînes de caractères
#
# On peut parcourir une chaîne comme une liste, lettre par lettre :

# %%
# Démonstration : parcourir une chaîne
for lettre in "informatique":
    print(lettre, end=" ")

# %% [markdown]
# <div style="background-color:#f0eafa; border-left:5px solid #8e44ad; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Application — Exemple complet à imiter — Parcourir une chaine</b><br>
# Cette fonction compte les occurrences de la lettre <code>'a'</code> dans un mot.<br>
# Repérez : l'accumulateur, la boucle sur la chaine, la condition, le return.
# </div>

# %%
# Exemple complet : compter les "a" dans un mot
def compter_a(mot):
    compteur = 0              # accumulateur initialise a 0
    for lettre in mot:        # on parcourt chaque lettre
        if lettre == "a":     # condition
            compteur = compteur + 1
    return compteur

print(compter_a("ananas"))       # affiche : 3
print(compter_a("informatique")) # affiche : 1
print(compter_a("python"))       # affiche : 0

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 4 a — Compter les lettres d'un mot</b>
# </div>

# %% [markdown]
# Écrire une fonction qui prend un **mot** en paramètre et retourne le **nombre de lettres**
# (sans utiliser `len()`). Tester avec au moins 2 mots.
# Que retourne votre fonction pour une chaîne vide ? Est-ce cohérent ?

# %%
# Exercice 4a — Complétez ici
def nb_lettres(mot):
    # Compter lettre par lettre, sans utiliser len()
    pass

print(nb_lettres("bonjour"))    # attendu : 7
print(nb_lettres("python"))     # attendu : 6
print(nb_lettres(""))           # attendu : 0 — est-ce cohérent ?

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 4b — Extraire les voyelles</b>
# </div>

# %% [markdown]
# Écrire une fonction qui prend un **mot** en paramètre et retourne les **voyelles** du mot.
# Par exemple : `voyelles("bonjour")` retourne `"oou"`.
#
# *Indication :* vous pouvez utiliser `if lettre in "aeiouy":`

# %%
# Exercice 4b — Complétez ici
def voyelles(mot):
    # Indice : if lettre in "aeiouy":
    pass

print(voyelles("bonjour"))       # attendu : "oou"
print(voyelles("informatique"))  # attendu : "ioaiue"

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 4c — Voyelles et consonnes (deux valeurs de retour)</b>
# </div>

# %% [markdown]
# Modifier la fonction précédente pour qu'elle retourne **les voyelles ET les consonnes**.
#
# *Indication :* pour retourner deux valeurs :
# ```python
# return a, b
# ```
# Et pour récupérer ces deux valeurs :
# ```python
# v, c = voyelles_consonnes(mot)
# ```

# %%
# Exercice 4c — Complétez ici
def voyelles_consonnes(mot):
    # Retourner deux valeurs : voyelles et consonnes
    pass

v, c = voyelles_consonnes("bonjour")
print("Voyelles :", v)    # attendu : "oou"
print("Consonnes :", c)   # attendu : "bnjr"

# %% [markdown]
# <div style="background-color:#f0eafa; border-left:5px solid #8e44ad; padding:14px 18px; border-radius:4px; margin:14px 0;">
# <b>Application — Exemple complet à imiter — Fonction qui renvoie un booléen</b><br>
# Cette fonction vérifie si un nombre est <b>positif</b>.<br>
# Observez comment une condition permet de renvoyer <code>True</code> ou <code>False</code>.
# </div>

# %%
# Exemple complet : verifier si un nombre est positif
def est_positif(n):
    if n > 0:
        return True
    else:
        return False

print(est_positif(5))    # True
print(est_positif(-3))   # False
print(est_positif(0))    # False — 0 n'est pas positif

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 5 — Vérifier un intervalle</b>
# </div>

# %% [markdown]
# Écrire une fonction qui vérifie si une valeur est dans un certain intervalle.
# Par exemple : `verifier(47, 0, 100)` retourne `True` car 47 est compris entre 0 et 100.
# Tester pour obtenir une fois `True` et une fois `False`.

# %%
# Exercice 5 — Complétez ici
def verifier(valeur, borne_min, borne_max):
    pass

print(verifier(47, 0, 100))    # True
print(verifier(150, 0, 100))   # False

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 6 — Liste des nombres pairs</b>
# </div>

# %% [markdown]
# Écrire une fonction qui prend en paramètre une **liste de nombres** et retourne
# une nouvelle liste ne contenant que les **nombres pairs**.
# Par exemple : `liste_paire([1, 2, 3, 5, 10, 11, 12])` retourne `[2, 10, 12]`.
# Que fait votre fonction si la liste ne contient que des nombres impairs ?

# %%
# Exercice 6 — Complétez ici
def liste_paire(liste):
    pass

print(liste_paire([1, 2, 3, 5, 10, 11, 12]))  # attendu : [2, 10, 12]
print(liste_paire([1, 3, 5, 7]))               # attendu : [] — cohérent ?

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 7 — Simulation de deux dés</b>
# </div>

# %% [markdown]
# Écrire une fonction qui tire **deux nombres aléatoires entre 1 et 6** et
# retourne `True` si ces nombres sont égaux, `False` sinon.
# Tester la fonction **10 fois** à l'aide d'une boucle `for`.

# %%
from random import randint

# Exercice 7 — Complétez ici
def double_de():
    # Tirer deux dés et retourner True si doublet
    pass

nb_doubles = 0
for _ in range(10):
    if double_de():
        nb_doubles += 1
        print("Double !")
    else:
        print("Pas de double")

print("\nNombre de doubles sur 10 lancers :", nb_doubles)

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #2980b9; padding:12px 16px; border-radius:4px; margin:12px 0;">
# <b>Exercice 8 — Calcul de moyenne (fonctions imbriquées)</b>
# </div>

# %% [markdown]
# Cet exercice illustre comment une fonction peut **appeler d'autres fonctions**.
#
# - **8a)** Écrire une fonction qui prend une liste et retourne la somme de ses éléments.
# - **8b)** Écrire une fonction qui prend une liste et retourne le nombre d'éléments (sans `len()`).
# - **8c)** Écrire une fonction qui retourne la **moyenne** — elle **doit** appeler les deux fonctions précédentes.

# %%
# Exercice 8a — somme des éléments d'une liste
def somme(liste):
    pass

# Exercice 8b — nombre d'éléments (sans len)
def nb_elements(liste):
    pass

# Exercice 8c — moyenne (doit appeler somme et nb_elements)
def moyenne(liste):
    # Indice : utiliser somme(liste) et nb_elements(liste)
    pass

notes = [4, 5, 3, 6, 5, 4.5]
print("Somme :", somme(notes))         # attendu : 27.5
print("Nombre :", nb_elements(notes))  # attendu : 6
print("Moyenne :", moyenne(notes))     # attendu : 4.58...

# %% [markdown]
# ---
# ## Exercice bonus — Mot à l'envers *(difficile)*
#
# Écrire une fonction qui prend un mot en paramètre et retourne ce mot **écrit à l'envers**.
# Par exemple : `envers("mot")` retourne `"tom"`.

# %%
# Exercice bonus — Complétez ici
def envers(mot):
    # Construire la chaîne lettre par lettre en sens inverse
    pass

print(envers("mot"))    # attendu : "tom"
print(envers("python")) # attendu : "nohtyp"

# %% [markdown]
# ---
# <div style="background-color:#1a1a2e; padding:20px; border-radius:10px; margin-top:30px;">
#   <h2 style="color:#e94560; font-family:monospace;">Récapitulatif</h2>
#   <table style="color:#a8a8b3; width:100%;">
#     <tr>
#       <th style="color:#e94560; text-align:left;">Type</th>
#       <th style="color:#e94560;">Paramètres</th>
#       <th style="color:#e94560;">return</th>
#       <th style="color:#e94560;">Exemple</th>
#     </tr>
#     <tr><td>Simple</td><td>Non</td><td>Non</td><td><code>def compteur3():</code></td></tr>
#     <tr><td>Calcul fixe</td><td>Non</td><td>Oui</td><td><code>def trois_au_cube():</code></td></tr>
#     <tr><td>Calcul variable</td><td>Oui</td><td>Oui</td><td><code>def cube(n):</code></td></tr>
#     <tr><td>Multi-paramètres</td><td>Oui (n)</td><td>Oui</td><td><code>def puissance(a, b):</code></td></tr>
#   </table>
#   <p style="color:#a8a8b3; margin-top:15px;">
#     <b style="color:#e94560;">Variables :</b>
#     locale = existe seulement à l'intérieur de la fonction |
#     globale = visible partout mais non modifiable par la fonction
#   </p>
# </div>

# %% [markdown]
# <div style="background-color:#27ae60; padding:12px 20px; border-radius:6px; margin:20px 0; text-align:center;">
#   <b style="color:white; font-size:1.1em;">Fin de la séance 2</b>
#   <b style="color:white; font-size:1.1em;">   --> Exercices supplémentaires</b>
# </div>
