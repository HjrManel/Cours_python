# %% [markdown]
# <div style="background-color:#ecf0f1; border-left:6px solid #e74c3c; padding:20px 30px; border-radius:6px;">
#   <h1 style="color:#2c3e50; margin:0;">Séance 6 &mdash; Les Listes en Python &mdash; suite</h1>
#   <p style="color:#7f8c8d; margin:8px 0 0 0;">
#     <em>"Un programme informatique fait ce que vous lui dites de faire, pas ce que vous voudriez."</em><br>
#     <span style="color:#1a1a2e;">Actions : accéder, trancher, ajouter, supprimer, trier, parcourir.</span>
#   </p>
# </div>

# %% [markdown]
# ---
# ## Rappel &mdash; Qu'est-ce qu'une liste ?
#
# Une <b style="color:#e74c3c;">liste</b> est une <b style="color:#e74c3c;">structure de données</b> : une manière d'organiser une collection de données.<br>
# En Python, la liste est une structure <b style="color:#e74c3c;">ordonnée</b>, dont chaque élément est accessible par son <b style="color:#e74c3c;">indice</b>.<br><br>
# Les éléments peuvent être de types différents. L'indice du premier élément est toujours <code>0</code>.

# %%
# Creation et affichage d'une liste
villes = ["Geneve", "Nyon", "Morges", "Lausanne"]
print(villes)
print(type(villes))

# %% [markdown]
# ---
# ## 1. Accès à un élément
#
# ### Accès par indice positif ou négatif

# %% [markdown]
# <div style="background-color:#e8f4f8; border-left:5px solid #306998; padding:15px; border-radius:6px; margin:10px 0;">
#   <b style="color:#306998;">Principe :</b>
#   <ul>
#     <li>Accès depuis le début &mdash; <code>liste[0]</code> est le premier élément de la liste.</li>
#     <li>Accès en sens inverse &mdash; <code>liste[-1]</code> est le dernier élément de la liste.</li>
#
#   </ul>
# </div>

# %%
# Exemple d'acces par indice
villes = ["Geneve", "Nyon", "Morges", "Lausanne"]

premiere = villes[0]     # premier element
quatrieme = villes[3]    # quatrieme element
derniere = villes[-1]    # dernier element (indice negatif)

print("Premier :", premiere)
print("Quatrieme :", quatrieme)
print("Dernier (indice -1) :", derniere)

# %%
# Modification d'un element a un indice donne
villes[1] = "Rolle"    # remplace "Nyon" par "Rolle"
print("Liste mise a jour :", villes)

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 1 &mdash; Accès par indice</b><br>
# Soit la liste : <code>villes = ["Geneve", "Nyon", "Morges", "Lausanne"]</code><br>
# 1. Quel élément se trouve à l'indice 0 ? Et à l'indice 3 ?<br>
# 2. Afficher la dernière ville avec un indice négatif.<br>
# 3. Modifier "Nyon" par "Rolle" et afficher la liste mise à jour.
# </div>

# %%
# Exercice 1 — Completez ici
villes = ["Geneve", "Nyon", "Morges", "Lausanne"]

# 1. Afficher l'element a l'indice 0 et a l'indice 3
print(villes[0])
print(villes[3])

# 2. Afficher le dernier element avec un indice negatif
print(villes[-1])

# 3. Modifier "Nyon" par "Rolle"
villes[1] = "Rolle"
print(villes)

# %% [markdown]
# ---
# ## 2. Tranches (slices)
#
# Une tranche copie une partie de la liste.<br>
# Le début est <b style="color:#e74c3c;">inclus</b>, la fin est <b style="color:#e74c3c;">exclue</b>.
#
# | Syntaxe    | Signification                                |
# |------------|----------------------------------------------|
# | `lst[:]`   | Copie complète de la liste                   |
# | `lst[m:]`  | Du m-ième élément jusqu'à la fin             |
# | `lst[:n]`  | Du début jusqu'au n-ième élément exclu       |
# | `lst[m:n]` | Du m-ième au n-ième élément (n exclu)        |

# %%
# Exemple complet de tranches
jours = ["lu", "ma", "me", "je", "ve", "sa", "di"]

print(jours)          # liste complete
print(jours[3])       # element a l'indice 3
print(type(jours))    # <class 'list'>
print(type(jours[3])) # <class 'str'>

print(jours[2:5])     # indices 2, 3, 4 => ["me", "je", "ve"]
print(jours[3:])      # du jeudi jusqu'a la fin
print(jours[:4])      # du debut jusqu'au 4eme exclu

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 2 &mdash; Tranches</b><br>
# Soit la liste : <code>sportifs = ["Ana", "Leo", "Sam", "Mia", "Tom"]</code><br>
# 1. Afficher les éléments de l'indice 1 à 3 (inclus).<br>
# 2. Afficher les éléments à partir de l'indice 2 jusqu'à la fin.<br>
# 3. Afficher une copie complète de la liste.<br>
# 4. Afficher le dernier élément avec un indice négatif.<br>
# 5. Quelle différence entre <code>sportifs[1:3]</code> et <code>sportifs[1:4]</code> ?
# </div>

# %%
# Exercice 2 — Completez ici
sportifs = ["Ana", "Leo", "Sam", "Mia", "Tom"]

# 1. Indices 1 a 3 inclus
print(sportifs[1:4])

# 2. A partir de l'indice 2
print(sportifs[2:])

# 3. Copie complete
print(sportifs[:])

# 4. Dernier element
print(sportifs[-1])

# 5. Difference : [1:3] => 2 elements, [1:4] => 3 elements
print(sportifs[1:3])
print(sportifs[1:4])

# %% [markdown]
# ---
# ## 3. Ajouter un élément
#
# - <b style="color:#e74c3c;">append(el)</b> : ajoute à la fin
# - <b style="color:#e74c3c;">insert(pos, el)</b> : insère à une position donnée (les suivants sont décalés)

# %%
# Exemple : ajouter des elements
liste = [2, 4, 6, 8, 10, 12]

liste.append(14)      # ajout en fin de liste
print("Apres append :", liste)

liste.insert(2, 999)  # insertion a l'indice 2
print("Apres insert :", liste)

# %%
# Inserer entre deux elements existants
villes = ["Geneve", "Morges"]
villes.insert(1, "Nyon")   # insere "Nyon" entre "Geneve" et "Morges"
print(villes)

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 3 &mdash; Ajouter un élément</b><br>
# Soit la liste : <code>resultats = [12, 17, 9, 15]</code><br>
# 1. Ajouter la valeur 20 à la fin de la liste.<br>
# 2. Insérer la valeur 5 à la position 2.<br>
# 3. Afficher la liste après chaque opération.
# </div>

# %%
# Exercice 3 — Completez ici
resultats = [12, 17, 9, 15]

# 1. Ajouter 20 a la fin
resultats.append(20)
print("Apres append :", resultats)

# 2. Inserer 5 a la position 2
resultats.insert(2, 5)
print("Apres insert :", resultats)

# %% [markdown]
# ---
# ## 4. Supprimer un élément
#
# - <b style="color:#e74c3c;">remove(el)</b> : supprime la première occurrence de la valeur
# - <b style="color:#e74c3c;">pop(pos)</b> : supprime l'élément à la position donnée et le retourne

# %%
# Exemple : supprimer des elements
jours = ["lu", "ma", "me", "je", "ve", "sa", "di"]

jours.remove("ve")       # supprime la valeur "ve"
print("Apres remove :", jours)

retire = jours.pop(1)    # supprime l'element a l'indice 1 et le memorise
print("Element retire :", retire)
print("Liste finale :", jours)

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 4 &mdash; Supprimer un élément</b><br>
# Soit la liste : <code>fruits = ["pomme", "banane", "cerise", "kiwi", "banane"]</code><br>
# 1. Supprimer la première occurrence de "banane".<br>
# 2. Supprimer l'élément à la position 0 et stocker sa valeur dans <code>retire</code>.<br>
# 3. Afficher la liste et la valeur retirée.
# </div>

# %%
# Exercice 4 — Completez ici
fruits = ["pomme", "banane", "cerise", "kiwi", "banane"]

# 1. Supprimer la premiere occurrence de "banane"
fruits.remove("banane")
print("Apres remove :", fruits)

# 2. Supprimer l'element a la position 0
retire = fruits.pop(0)

# 3. Afficher
print("Element retire :", retire)
print("Liste finale :", fruits)

# %% [markdown]
# ---
# ## 5. Trier une liste
#
# La méthode <b style="color:#e74c3c;">sort()</b> trie la liste en place (la liste originale est modifiée).<br>
# Le tri suit l'ordre <b style="color:#e74c3c;">ASCII</b> : majuscules avant minuscules, puis ordre alphabétique.<br>
#
# <div style="background-color:#f8d7da; border-left:5px solid #dc3545; padding:12px; border-radius:4px;">
# <b>Attention</b> — Tous les éléments doivent être du <b>même type</b> pour trier une liste.
# </div>

# %%
# Tri ascendant et descendant
fruits = ["poire", "banane", "abricot", "cerise"]

fruits.sort()             # tri alphabetique croissant
print("Croissant :", fruits)

fruits.sort(reverse=True) # tri alphabetique decroissant
print("Decroissant :", fruits)

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 5 &mdash; Trier une liste</b><br>
# Soit la liste : <code>scores = [45, 12, 78, 33, 91, 5]</code><br>
# 1. Trier par ordre croissant et afficher.<br>
# 2. Trier par ordre décroissant et afficher.<br>
# 3. <code>noms = ["Zoe", "alice", "Bernard", "max"]</code> — dans quel ordre <code>sort()</code> classe-t-il ces prénoms ? Vérifiez.
# </div>

# %%
# Exercice 5 — Completez ici
scores = [45, 12, 78, 33, 91, 5]

# 1. Ordre croissant
scores.sort()
print("Croissant :", scores)

# 2. Ordre decroissant
scores.sort(reverse=True)
print("Decroissant :", scores)

# 3. Tri de prenoms (majuscules avant minuscules selon l'ordre ASCII)
noms = ["Zoe", "alice", "Bernard", "max"]
noms.sort()
print("Noms tries :", noms)

# %% [markdown]
# ---
# ## 6. Choisir un élément aléatoire : random.choice()
#
# La fonction <b style="color:#e74c3c;">choice()</b> du module <code>random</code> retourne un seul élément choisi au hasard dans une liste.

# %%
from random import choice

couleurs = ["rouge", "vert", "bleu"]
tirage = choice(couleurs)   # element aleatoire
print("Couleur tiree :", tirage)

# %%
from random import choice

# Tirer 20 fruits et compter les occurrences
fruits = ["Banane", "Abricot", "Cerise", "Poire"]
compteur = {}

for _ in range(20):
    fruit = choice(fruits)
    compteur[fruit] = compteur.get(fruit, 0) + 1

print("Resultats apres 20 tirages :", compteur)

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 6 &mdash; random.choice()</b><br>
# Soit la liste : <code>equipe = ["Alice", "Bruno", "Clara", "Diego", "Eva"]</code><br>
# 1. Désigne un capitaine au hasard et affiche : <em>"Le capitaine est : [nom]"</em><br>
# 2. Simule un tirage de 10 capitaines successifs.
# </div>

# %%
from random import choice

equipe = ["Alice", "Bruno", "Clara", "Diego", "Eva"]

# 1. Tirer un capitaine
capitaine = choice(equipe)
print("Le capitaine est :", capitaine)

# 2. Simuler 10 tirages successifs
for i in range(1, 11):
    cap = choice(equipe)
    print("Tirage", i, ":", cap)

# %% [markdown]
# ---
# ## 7. Liste de listes
#
# Une liste peut contenir d'autres listes comme éléments.<br>
# Pour accéder à un élément imbriqué, on chaîne les indices : <b style="color:#e74c3c;">liste[i][j]</b>

# %%
# Exemple : liste de listes imbriquees
etats = [["chaud", "tiede", ["froid", "glace"]], ["lumineux", "eclaire", "sombre"]]

# "lumineux" : 2e tableau (ind 1), 1er element (ind 0)
e1 = etats[1][0]
print("lumineux :", e1)

# "glace" : 1er tableau (ind 0), 3e element (ind 2), 2e choix (ind 1)
e2 = etats[0][2][1]
print("glace :", e2)

# "froid" : 1er tableau (ind 0), 3e element (ind 2), 1er choix (ind 0)
e3 = etats[0][2][0]
print("froid :", e3)

# Modifier "sombre" par "fonce"
etats[1][2] = "fonce"
print("Liste modifiee :", etats)

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 7 &mdash; Liste de listes</b><br>
# Soit la liste : <code>classement = [["Ana", 1], ["Leo", 2], ["Sam", 3]]</code><br>
# 1. Afficher le nom du premier classé.<br>
# 2. Modifier le rang de "Leo" pour lui attribuer la position 1.
# </div>

# %%
# Exercice 7 — Completez ici
classement = [["Ana", 1], ["Leo", 2], ["Sam", 3]]

# 1. Nom du premier classe
print("Premier classe :", classement[0][0])

# 2. Modifier le rang de "Leo"
classement[1][1] = 1
print("Classement mis a jour :", classement)

# %% [markdown]
# ---
# ## 8. Taille d'une liste : len()
#
# <b style="color:#e74c3c;">len(liste)</b> retourne le nombre d'éléments de <b>premier niveau</b> de la liste.

# %%
# Exemples de len()
jours = ["lu", "ma", "me", "je", "ve", "sa", "di"]
print("Taille jours :", len(jours))    # 7

vide = []
print("Taille vide :", len(vide))      # 0

# Seuls les elements de premier niveau sont comptes
multi = [["x","y","z"], [[1,2],[3,4]], [1,2,3], "a", 10]
print("Taille multi :", len(multi))    # 5

# %%
# Verification sur des listes variees
fruits  = ["banane", "abricot", "cerise", "poire"]
nombres = [1, 2, 3, 4, 5]
etrange = [[], [[], []], [], [], [[], []]]

print("fruits :", len(fruits))    # 4
print("nombres :", len(nombres))  # 5
print("etrange :", len(etrange))  # 5

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:5px solid #ffc107; padding:12px; border-radius:4px;">
# <b>Exercice 8 &mdash; Taille d'une liste</b><br>
# Soit la liste : <code>equipe = ["Alice", "Bruno", "Clara", "Diego"]</code><br>
# 1. Afficher la taille avec <code>len()</code>.<br>
# 2. Ajouter un nom, puis ré-afficher la taille.<br>
# 3. Supprimer un élément, puis ré-afficher la taille.<br>
# 4. Que vaut <code>len([[1,2],[3,4],[5]])</code> ? Pourquoi ?
# </div>

# %%
# Exercice 8 — Completez ici
equipe = ["Alice", "Bruno", "Clara", "Diego"]

# 1. Taille initiale
print("Taille initiale :", len(equipe))

# 2. Ajouter un nom
equipe.append("Eva")
print("Apres ajout :", len(equipe))

# 3. Supprimer un element
equipe.pop(0)
print("Apres suppression :", len(equipe))

# 4. Trois sous-listes de premier niveau => 3
print("len([[1,2],[3,4],[5]]) =", len([[1,2],[3,4],[5]]))

# %% [markdown]
# ---
# ## 9. Opérateurs + et * sur les listes
#
# <div style="background-color:#e8f4f8; border-left:5px solid #306998; padding:15px; border-radius:6px; margin:10px 0;">
#   <b style="color:#306998;">À retenir :</b>
#   <ul>
#     <li><code>lst1 + lst2</code> : concatène (assemble) deux listes</li>
#     <li><code>n * lst</code> : répète la liste n fois</li>
#     <li><code>lst1 * lst2</code> : impossible &mdash; Python lève une erreur</li>
#   </ul>
# </div>

# %%
# Operateurs + et * sur les listes
lst1 = [1, 2]
lst2 = [3, 4]

print("lst1 :", lst1)
print("lst2 :", lst2)

lst3 = lst1 + lst2       # concatenation
print("lst1 + lst2 :", lst3)

lst4 = 2 * lst1          # repetition
print("2 * lst1 :", lst4)

lst5 = 10 * []           # liste vide repetee => liste vide
print("10 * [] :", lst5)

lst6 = 10 * [0]          # dix zeros
print("10 * [0] :", lst6)

# lst7 = lst1 * lst2    # ERREUR : TypeError — decommentez pour verifier
# print(lst7)

# %% [markdown]
# ---
# ## 10. Exercices de synthèse
#
# ### Exercice A &mdash; Parcourir une liste avec son indice
#
# Afficher chaque élément d'une liste sur une ligne séparée, avec son indice.

# %%
# Parcourir une liste avec son indice
langages = ["Python", "Java", "C", "JavaScript"]

for i in range(len(langages)):
    print(i, "->", langages[i])

# %% [markdown]
# ### Exercice B &mdash; Test d'appartenance
#
# Tester la présence ou l'absence d'un élément avec <code>in</code> / <code>not in</code>.

# %%
# Test d'appartenance avec in / not in
courses = ["pain", "lait", "fromage", "beurre"]

if "lait" in courses:
    print("Le lait est dans la liste")

if "jus" not in courses:
    print("Le jus n'est pas dans la liste")

# %% [markdown]
# ### Exercice C &mdash; Construire une liste par accumulation
#
# Demander des notes à l'utilisateur, les stocker dans une liste, puis calculer la moyenne.

# %%
# Construction d'une liste par accumulation
notes = []
n = int(input("Combien de notes ? "))

for i in range(n):
    note = float(input("Note " + str(i+1) + " : "))
    notes.append(note)

# sum() calcule la somme des elements
moyenne = sum(notes) / len(notes)
print("Notes :", notes)
print("Moyenne :", moyenne)

# %% [markdown]
# ### Exercice D &mdash; Nettoyer une liste
#
# Construire une nouvelle liste en retirant tous les zéros d'une liste d'origine.

# %%
# Retirer tous les zeros d'une liste
donnees = [3, 0, 7, 0, 1, 0, 9, 4]
propres = []

for val in donnees:
    if val != 0:
        propres.append(val)

print("Original :", donnees)
print("Nettoyee :", propres)

# %% [markdown]
# ---
# <div style="background-color:#f4f9f4; border-left:6px solid #27ae60; padding:20px 24px; border-radius:6px; margin-top:30px;">
#   <h2 style="color:#1e8449; font-family:monospace; margin:0 0 14px 0;">Récapitulatif</h2>
#   <table style="color:#2c3e50; width:100%; border-collapse:collapse;">
#     <tr style="border-bottom:2px solid #27ae60;">
#       <th style="text-align:left; padding:6px 10px; width:160px; color:#1e8449;">Action</th>
#       <th style="text-align:left; padding:6px 10px; color:#1e8449;">Syntaxe</th>
#       <th style="text-align:left; padding:6px 10px; color:#1e8449;">Exemple</th>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9;">
#       <td style="text-align:left; padding:6px 10px;">Accès</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst[i]</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">villes[0]</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9; background-color:#edf7ed;">
#       <td style="text-align:left; padding:6px 10px;">Tranche</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst[m:n]</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">jours[2:5]</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9;">
#       <td style="text-align:left; padding:6px 10px;">Modifier</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst[i] = val</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">lst[1] = "Rolle"</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9; background-color:#edf7ed;">
#       <td style="text-align:left; padding:6px 10px;">Ajouter fin</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst.append(el)</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">lst.append(14)</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9;">
#       <td style="text-align:left; padding:6px 10px;">Insérer</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst.insert(pos, el)</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">lst.insert(2, 999)</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9; background-color:#edf7ed;">
#       <td style="text-align:left; padding:6px 10px;">Supprimer valeur</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst.remove(el)</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">lst.remove("ve")</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9;">
#       <td style="text-align:left; padding:6px 10px;">Supprimer indice</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst.pop(i)</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">lst.pop(0)</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9; background-color:#edf7ed;">
#       <td style="text-align:left; padding:6px 10px;">Trier</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst.sort()</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">lst.sort(reverse=True)</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9;">
#       <td style="text-align:left; padding:6px 10px;">Taille</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">len(lst)</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">len(jours)</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9; background-color:#edf7ed;">
#       <td style="text-align:left; padding:6px 10px;">Appartenance</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">el in lst</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">"lait" in courses</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9;">
#       <td style="text-align:left; padding:6px 10px;">Aléatoire</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">choice(lst)</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">choice(couleurs)</code></td>
#     </tr>
#     <tr style="border-bottom:1px solid #c8e6c9; background-color:#edf7ed;">
#       <td style="text-align:left; padding:6px 10px;">Concaténation</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">lst1 + lst2</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">[1,2] + [3,4]</code></td>
#     </tr>
#     <tr>
#       <td style="text-align:left; padding:6px 10px;">Répétition</td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#1565c0;">n * lst</code></td>
#       <td style="text-align:left; padding:6px 10px;"><code style="color:#2e7d32;">10 * [0]</code></td>
#     </tr>
#   </table>
# </div>
